# %% [markdown]
# <a href="https://colab.research.google.com/github/harishswamiduraiprabakar/NLP/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
input = "hi i am harish. how are you"
output1 = sent_tokenize(input)
print(output1)
# Out:
# ['hi i am harish.', 'how are you']

# %%
pip install spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %%
! python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
for token in doc:
    print(token)
# Out:
# This
# is
# a
# sentence
# .
